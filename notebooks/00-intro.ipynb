# %% [markdown]
# # Synthetic DataSet Generator
#
# Bienvenido al proyecto. Este notebook usa el kernel **Python (Synthetic DataSet)**.

# %%
import sys
print(f"Python {sys.version}")
print(f"Kernel: {sys.executable}")

# %%
# Imports generales
import time
import random
import os
from io import StringIO
from pathlib import Path

# Data Science
import torch
import numpy as np
import pandas as pd

# APIs y DB
from openai import OpenAI
from sqlalchemy import create_engine

# UI
import gradio as gr

# Hugging Face
from huggingface_hub import login
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig

# ---- Reemplazo de google.colab ----
# from google.colab import drive, userdata  <-- NO funciona localmente
# Alternativa local:
from dotenv import load_dotenv
load_dotenv()  # Carga variables desde .env

# En lugar de google.colab.drive.mount('/content/drive')
# usamos rutas locales:
DRIVE_PATH = Path("data")  # Cambiá esto a tu ruta local

# En lugar de userdata.get('OPENAI_API_KEY')
# usamos variables de entorno:
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
HUGGINGFACE_TOKEN = os.getenv("HUGGINGFACE_TOKEN")

print("Todos los imports cargados correctamente")
print(f"Torch: {torch.__version__}, NumPy: {np.__version__}, Pandas: {pd.__version__}")
print(f"DRIVE_PATH local: {DRIVE_PATH.resolve()}")

# %%
# Test rápido de torch
if torch.cuda.is_available():
    print(f"CUDA disponible: {torch.cuda.get_device_name(0)}")
else:
    print("CUDA no disponible, usando CPU")

tensor = torch.randn(3, 3)
print(f"Tensor test:\n{tensor}")
